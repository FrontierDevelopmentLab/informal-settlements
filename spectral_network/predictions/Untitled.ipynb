# %%
import numpy as np
import glob
import os
import sys

cwd = os.getcwd()
base = '/prediction_with_'
end = '_metrics.dat'
countries = {'Colombia', 'India', 'Kenya', 'Nigeria', 'Southafrica', 'Sudan'}
allcities = ['Mumbai', 'Capetown','Lower','Kibera','Kianda', 'AlGeneina','ElDaein','Mokako','Medellin']
alldata  = []
citymap =  {'India':['Mumbai'], 'Southafrica':['Capetown'],'Kenya':['Lower','Kibera','Kianda'],'Sudan': ['AlGeneina','ElDaein'],'Nigeria':['Mokako'],'Colombia':['Medellin']}
for file in os.listdir(cwd):
    if file in countries:
        cities = citymap[file]
        print('Country : {}'.format(file))
        for city in cities:
            print('City : {}\n'.format(city))
            for model in allcities:
                path = cwd + '/' + file + '/' + city + base + model +end
                try:
                    with open(path, 'r') as f:
                        lines = f.readlines()
                        string = 'Model Used : {2}\n'.format(file,city,model)
                        for line in lines:
                            string = string + line
                        print(string)
                except FileNotFoundError:
                    continue
# Out:
# Country : Colombia
# City : Medellin
#
# Model Used : Mumbai
# mean IOU : 0.56110
# Informal classification :  0.70052
# Environment classification :  0.45612
#
# Model Used : Capetown
# mean IOU : 0.48148
# Informal classification :  0.96389
# Environment classification :  0.11822
#
# Model Used : Lower
# mean IOU : 0.63186
# Informal classification :  0.53401
# Environment classification :  0.70555
#
# Model Used : Kibera
# mean IOU : 0.62646
# Informal classification :  0.38717
# Environment classification :  0.80665
#
# Model Used : Kianda
# mean IOU : 0.64190
# Informal classification :  0.35832
# Environment classification :  0.85544
#
# Model Used : AlGeneina
# mean IOU : 0.61795
# Informal classification :  0.82237
# Environment classification :  0.46401
#
# Model Used : ElDaein
# mean IOU : 0.55446
# Informal classification :  0.18037
# Environment classification :  0.83615
#
# Model Used : Mokako
# mean IOU : 0.53825
# Informal classification :  0.13395
# ...

# %%
import numpy as np
import glob
import os
import sys

cwd = os.getcwd()
base = '/prediction_with_'
end = '_metrics.dat'
countries = {'Colombia', 'India', 'Kenya', 'Nigeria', 'Southafrica', 'Sudan'}
allcities = ['Mumbai', 'Capetown','Lower','Kibera','Kianda', 'AlGeneina','ElDaein','Mokako','Medellin']
alldata  = []
citymap =  {'India':['Mumbai'], 'Southafrica':['Capetown'],'Kenya':['Lower','Kibera','Kianda'],'Sudan': ['AlGeneina','ElDaein'],'Nigeria':['Mokako'],'Colombia':['Medellin']}
for file in os.listdir(cwd):
    if file in countries:
        cities = citymap[file]
        print('Country : {}'.format(file))
        for city in cities:
            print('City : {}\n'.format(city))
            for model in allcities:
                path = cwd + '/' + file + '/' + city + base + model +end
                try:
                    with open(path, 'r') as f:
                        lines = f.readlines()
                        string = 'Model Used : {2}\n'.format(file,city,model)
                        for line in lines:
                            string = string + line
                        print(string)
                except FileNotFoundError:
                    continue
# Out:
# Country : Colombia
# City : Medellin
#
# Model Used : Mumbai
# mean IOU : 0.56110
# Informal classification :  0.70052
# Environment classification :  0.45612
#
# Model Used : Capetown
# mean IOU : 0.48148
# Informal classification :  0.96389
# Environment classification :  0.11822
#
# Model Used : Lower
# mean IOU : 0.63186
# Informal classification :  0.53401
# Environment classification :  0.70555
#
# Model Used : Kibera
# mean IOU : 0.62646
# Informal classification :  0.38717
# Environment classification :  0.80665
#
# Model Used : Kianda
# mean IOU : 0.64190
# Informal classification :  0.35832
# Environment classification :  0.85544
#
# Model Used : AlGeneina
# mean IOU : 0.61795
# Informal classification :  0.82237
# Environment classification :  0.46401
#
# Model Used : ElDaein
# mean IOU : 0.55446
# Informal classification :  0.18037
# Environment classification :  0.83615
#
# Model Used : Mokako
# mean IOU : 0.53825
# Informal classification :  0.13395
# ...
